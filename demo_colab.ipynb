# %% [markdown]
# # 🚀 Dual-Loop OS: 1-Click Verification & Benchmark Harness
# Official Google Colab Demo for **Dual-Loop OS: A Formal Neuro-Symbolic Framework with Deterministic Barrier Constraints**.
#
# Click **Runtime -> Run all** (`Ctrl+F9`) to execute all 5 core mathematical and empirical verification checkpoints in **< 0.5s** on standard CPU.

# %%
# Run the zero-dependency verification suite directly
# !python demo_colab.py

# %%
# Run the CartPole-v1 50,000-step physical simulation
# !python benchmarks/run_cartpole_cbf.py
